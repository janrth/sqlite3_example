# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import unittest
import sqlite3
import db

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
#which python I used:
print("You are using Python {}.{}.".format(sys.version_info.major, sys.version_info.minor))
# Out:
# You are using Python 3.7.

# %% [raw]
# I create a sqlite database from a csv file in my folder. Then I query this database and create a csv in my notebook.

# %%
#Initialize class to create databases for train and ideal
y = db.database()

#make train db
y.training_db()

#make ideal db
y.ideal_db()

#load in pandas df:
conn_train = sqlite3.connect('train.db')
conn_ideal = sqlite3.connect('ideal.db')

train = pd.read_sql_query("SELECT * FROM train", conn_train)
ideal = pd.read_sql_query("SELECT * FROM ideal", conn_ideal)

print(train.shape,
      ideal.shape)
# Out:
# (400, 5) (400, 51)

# %%
train.head()
# Out:
#       x         y1         y2         y3         y4
# 0 -20.0 -5832.4746 -23995.062  20.146387 -8019.7290
# 1 -19.9 -5735.4526 -23636.361  19.725082 -7900.1084
# 2 -19.8 -5640.1460 -23282.260  20.013353 -7781.9330
# 3 -19.7 -5545.7000 -22930.621  19.511282 -7665.3823
# 4 -19.6 -5452.1196 -22583.277  20.173714 -7549.1030

# %%
ideal.head()
# Out:
#       x        y1        y2        y3        y4        y5        y6        y7        y8        y9        y10   y11   y12   y13   y14    y15     y16     y17     y18     y19     y20       y21       y22       y23        y24        y25       y26        y27       y28       y29       y30   y31       y32        y33       y34   y35    y36   y37       y38        y39        y40        y41        y42       y43       y44        y45       y46       y47       y48       y49       y50
# 0 -20.0 -0.912945  0.408082  9.087055  5.408082 -9.087055  0.912945 -0.839071 -0.850919  0.816164  18.258905 -20.0 -58.0 -45.0  20.0  13.00  400.00 -400.00  800.00  410.00  289.00 -8000.000  8000.000  8000.000 -16000.000 -23995.000 -5832.000  10648.000 -8020.000 -7600.000 -8795.000  20.0  4.472136  20.124610 -0.746414  10.0  100.0 -20.0 -1.321027  399.08707  899.59190 -40.456474  40.204040  2.995732 -0.008333  12.995732  5.298317 -5.298317 -0.186278  0.912945  0.396850
# ...
